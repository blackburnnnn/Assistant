# %%
for a in range(1,101): 
    for b in range (1,101-a):
        for c in range(1,101-a-b):
            if 3*a+2*b+c/3==100:  
                print("一共买了只母鸡%d，%d只公鸡，%d只小鸡。"%(a,b,c))
                continue
# Out:
# 一共买了只母鸡1，39只公鸡，57只小鸡。
# 一共买了只母鸡1，40只公鸡，51只小鸡。
# 一共买了只母鸡1，41只公鸡，45只小鸡。
# 一共买了只母鸡1，42只公鸡，39只小鸡。
# 一共买了只母鸡1，43只公鸡，33只小鸡。
# 一共买了只母鸡1，44只公鸡，27只小鸡。
# 一共买了只母鸡1，45只公鸡，21只小鸡。
# 一共买了只母鸡1，46只公鸡，15只小鸡。
# 一共买了只母鸡1，47只公鸡，9只小鸡。
# 一共买了只母鸡1，48只公鸡，3只小鸡。
# 一共买了只母鸡2，37只公鸡，60只小鸡。
# 一共买了只母鸡2，38只公鸡，54只小鸡。
# 一共买了只母鸡2，39只公鸡，48只小鸡。
# 一共买了只母鸡2，40只公鸡，42只小鸡。
# 一共买了只母鸡2，41只公鸡，36只小鸡。
# 一共买了只母鸡2，42只公鸡，30只小鸡。
# 一共买了只母鸡2，43只公鸡，24只小鸡。
# 一共买了只母鸡2，44只公鸡，18只小鸡。
# 一共买了只母鸡2，45只公鸡，12只小鸡。
# 一共买了只母鸡2，46只公鸡，6只小鸡。
# 一共买了只母鸡3，36只公鸡，57只小鸡。
# 一共买了只母鸡3，37只公鸡，51只小鸡。
# 一共买了只母鸡3，38只公鸡，45只小鸡。
# 一共买了只母鸡3，39只公鸡，39只小鸡。
# 一共买了只母鸡3，40只公鸡，33只小鸡。
# 一共买了只母鸡3，41只公鸡，27只小鸡。
# 一共买了只母鸡3，42只公鸡，21只小鸡。
# 一共买了只母鸡3，43只公鸡，15只小鸡。
# 一共买了只母鸡3，44只公鸡，9只小鸡。
# 一共买了只母鸡3，45只公鸡，3只小鸡。
# 一共买了只母鸡4，34只公鸡，60只小鸡。
# 一共买了只母鸡4，35只公鸡，54只小鸡。
# 一共买了只母鸡4，36只公鸡，48只小鸡。
# 一共买了只母鸡4，37只公鸡，42只小鸡。
# 一共买了只母鸡4，38只公鸡，36只小鸡。
# 一共买了只母鸡4，39只公鸡，30只小鸡。
# 一共买了只母鸡4，40只公鸡，24只小鸡。
# 一共买了只母鸡4，41只公鸡，18只小鸡。
# 一共买了只母鸡4，42只公鸡，12只小鸡。
# 一共买了只母鸡4，43只公鸡，6只小鸡。
# 一共买了只母鸡5，32只公鸡，63只小鸡。
# ...
